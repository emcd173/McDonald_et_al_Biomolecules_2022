# %%
# begin by impoprting some useful libraries 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import math 
from sklearn.metrics import r2_score
from scipy import stats

# %%
cl_150_path = '../refinement_optimization/closed/rms_opt/1.5/'
cl_175_path = '../refinement_optimization/closed/rms_opt/1.75/'
cl_200_path = '../refinement_optimization/closed/rms_opt/2.0/'
cl_225_path = '../refinement_optimization/closed/rms_opt/2.25/'
cl_250_path = '../refinement_optimization/closed/rms_opt/2.5/'

op_150_path = '../refinement_optimization/open/rms_opt/1.5/'
op_175_path = '../refinement_optimization/open/rms_opt/1.75/'

# %%
rms = [1.5, 1.75, 2.0, 2.25, 2.5]

# %% [markdown]
# ## closed state

# %% [markdown]
# #### import data

# %%
cl_150_rmsd = []
for i in range(100):
    with open(cl_150_path + 'NBD1_RMSD/' + '5uak_WT_NBD1_rmsd_{}.pdb'.format(i)) as f:
        first_line = f.readline()
        x = first_line.split(' ')
        cl_150_rmsd.append(float(x[1]))
        
cl_150_score = []
for i in range(100): 
    fnm = cl_150_path +'scores/' + 'score_{}.sc'.format(i)
    x = np.genfromtxt(fnm, dtype = ['U15', 'float64'], skip_header = 1 )
    cl_150_score.append(float(x[1][1]))

# %%
cl_175_rmsd = []
for i in range(100):
    with open(cl_175_path + 'NBD1_RMSD/' + '5uak_WT_NBD1_rmsd_{}.pdb'.format(i)) as f:
        first_line = f.readline()
        x = first_line.split(' ')
        cl_175_rmsd.append(float(x[1]))
        
cl_175_score = []
for i in range(100): 
    fnm = cl_175_path +'scores/' + 'score_{}.sc'.format(i)
    x = np.genfromtxt(fnm, dtype = ['U15', 'float64'], skip_header = 1 )
    cl_175_score.append(float(x[1][1]))

# %%
cl_200_rmsd = []
for i in np.concatenate([range(0,35), range(36,100)]):
    with open(cl_200_path + 'NBD1_RMSD/' + '5uak_WT_NBD1_rmsd_{}.pdb'.format(i)) as f:
        first_line = f.readline()
        x = first_line.split(' ')
        cl_200_rmsd.append(float(x[1]))
        
cl_200_score = []
for i in np.concatenate([range(0,35), range(36,100)]): 
    fnm = cl_200_path +'scores/' + 'score_{}.sc'.format(i)
    x = np.genfromtxt(fnm, dtype = ['U15', 'float64'], skip_header = 1 )
    cl_200_score.append(float(x[1][1]))

# %%
cl_225_rmsd = []
for i in np.concatenate([range(0,50), range(51,100)]):
    with open(cl_225_path + 'NBD1_RMSD/' + '5uak_WT_NBD1_rmsd_{}.pdb'.format(i)) as f:
        first_line = f.readline()
        x = first_line.split(' ')
        cl_225_rmsd.append(float(x[1]))
        
cl_225_score = []
for i in np.concatenate([range(0,50), range(51,100)]): 
    fnm = cl_225_path +'scores/' + 'score_{}.sc'.format(i)
    x = np.genfromtxt(fnm, dtype = ['U15', 'float64'], skip_header = 1 )
    cl_225_score.append(float(x[1][1]))

# %%
cl_250_rmsd = []
for i in range(100):
    with open(cl_250_path + 'NBD1_RMSD/' + '5uak_WT_NBD1_rmsd_{}.pdb'.format(i)) as f:
        first_line = f.readline()
        x = first_line.split(' ')
        cl_250_rmsd.append(float(x[1]))

cl_250_score = []
for i in range(100): 
    fnm = cl_250_path +'scores/' + 'score_{}.sc'.format(i)
    x = np.genfromtxt(fnm, dtype = ['U15', 'float64'], skip_header = 1 )
    cl_250_score.append(float(x[1][1]))
    
cl_250_score = cl_250_score[1:100]
cl_250_rmsd = cl_250_rmsd[1:100]

# %% [markdown]
# #### plot

# %%
font =30

plt.figure(figsize = (24,12))

plt.scatter(cl_150_rmsd, cl_150_score, s=250, color='deepskyblue', edgecolor='k')
plt.scatter(cl_175_rmsd, cl_175_score, s=250, color='red',edgecolor='k')
#plt.scatter(cl_200_rmsd, cl_200_score,s=50, color='violet',edgecolor='k')
#plt.scatter(cl_225_rmsd, cl_225_score, s=50,color='lime',edgecolor='k')
#plt.scatter(cl_250_rmsd, cl_250_score,  s=50, color='gold',edgecolor='k')
plt.tick_params(axis='both', which='major', labelsize=font-10)
plt.xlabel('NBD1 RMSD', fontsize = font,  labelpad=20)
plt.ylabel('Score', fontsize = font,  labelpad=20)
plt.xlim(0,3.1)
plt.savefig('../figures/5uak_rms_insertion_optimization.svg', format='svg')

# %% [markdown]
# ## open state

# %% [markdown]
# #### import data

# %%
op_150_rmsd = []
for i in range(100):
    with open(op_150_path + 'NBD1_RMSD/' + '6msm_WT_NBD1_rmsd_{}.pdb'.format(i)) as f:
        first_line = f.readline()
        x = first_line.split(' ')
        op_150_rmsd.append(float(x[1]))
        
op_150_score = []
for i in range(100): 
    fnm = op_150_path +'scores/' + 'score_{}.sc'.format(i)
    x = np.genfromtxt(fnm, dtype = ['U15', 'float64'], skip_header = 1 )
    op_150_score.append(float(x[1][1]))

# %%
op_175_rmsd = []
for i in range(100):
    with open(op_175_path + 'NBD1_RMSD/' + '6msm_WT_NBD1_rmsd_{}.pdb'.format(i)) as f:
        first_line = f.readline()
        x = first_line.split(' ')
        op_175_rmsd.append(float(x[1]))
        
op_175_score = []
for i in range(100): 
    fnm = op_175_path +'scores/' + 'score_{}.sc'.format(i)
    x = np.genfromtxt(fnm, dtype = ['U15', 'float64'], skip_header = 1 )
    op_175_score.append(float(x[1][1]))

# %% [markdown]
# ### plot

# %%
font =30
#plt.scatter(cl_200_rmsd, cl_200_score, color='violet',edgecolor='k')
#plt.scatter(cl_225_rmsd, cl_225_score, color='lime',edgecolor='k')
#plt.scatter(cl_250_rmsd, cl_250_score, color='gold',edgecolor='k')
plt.figure(figsize = (24,12))
plt.scatter(op_150_rmsd, op_150_score, s=250, color='deepskyblue', edgecolor='k')
plt.scatter(op_175_rmsd, op_175_score, s=250, color='red',edgecolor='k')
plt.tick_params(axis='both', which='major', labelsize=font-10)
plt.xlabel('NBD1 RMSD', fontsize = font,  labelpad=20)
plt.ylabel('Score', fontsize = font,  labelpad=20)
plt.xlim(0,2.25)
plt.savefig('../figures/6msm_rms_insertion_optimization.svg', format='svg')
